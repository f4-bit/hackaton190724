# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from new_service import get_information_eltiempo

def obtener_articulos(paginas=100):
    """
    Extrae los nombres de los artículos, URLs y fechas de publicación de las páginas especificadas
    de la búsqueda en El Tiempo sobre migrantes venezolanos en Colombia.

    :param paginas: Número de páginas a procesar.
    :return: DataFrame con las columnas 'Título', 'Fecha de Publicación' y 'URL'.
    """
    # Lista para almacenar los datos
    datos = []

    # Iterar sobre las páginas
    for page in range(paginas):
        url = f'https://www.eltiempo.com/buscar/?q=migrantes%20venezolanos%20en%20colombia&sort_field=_score&articleTypes=default,gallery,especial_modular,especial-tipo-d,video_detail,play_video_detail&categories_ids_or=&from=2024-01-20&until=2024-07-20&page={page}'
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Lanza un error para códigos de estado HTTP 4xx/5xx

        # Parsear el contenido HTML del artículo
        soup = BeautifulSoup(response.content, 'html.parser')
        articulos = soup.find_all('article', class_='c-article')

        # Extraer los nombres, URLs y fechas de publicación de los artículos
        for articulo in articulos:
            # Encontrar el título del artículo
            titulo = articulo.find('h3', class_='c-article__title').get_text(strip=True)
            # Encontrar la URL del artículo
            url = articulo.find('a', class_='page-link')['href']
            url = 'https://www.eltiempo.com/' + url
            # Encontrar la fecha de publicación
            fecha_publicacion = articulo.find('time', class_='c-article__date').get_text(strip=True)
            
            # Añadir los datos a la lista
            datos.append({
                'title': titulo,
                'date': fecha_publicacion,
                'url': url
            })

    # Crear un DataFrame con los datos
    df = pd.DataFrame(datos)
    return df

# %%
articles = obtener_articulos(paginas=100)

# %%
articles['content'] = None
articles['#coments'] = None
articles['coments'] = None
articles['tags'] = None
for index, row in articles.iterrows():
    content, coments, tags = get_information_eltiempo(row['url'])
    # Agregar el contenido del articulo
    articles.loc[index, 'content'] = content
    if coments is not None:
        articles.loc[index, '#coments'] = len(coments)
        articles.loc[index, 'coments'] = coments
    if tags is not None:
        articles.loc[index, 'tags'] = tags
# Out:
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307699&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307699&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3306970&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3357905&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3284985&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307785&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3310142&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3285792&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3311815&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3339129&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3322629&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3340091&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3296649&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3285976&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3267927&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3166593&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3310078&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3285977&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3264925&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307330&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3267513&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307773&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3310943&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3296627&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3344489&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3306680&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3348162&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3306670&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3268920&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3336494&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3306800&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3322676&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3345474&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3340121&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3306803&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3359452&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3345430&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3306855&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3306801&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3331782&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3354693&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3288840&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3359304&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3356434&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3285671&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3334244&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3336576&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3306775&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3352726&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3266719&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3264371&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3336136&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307486&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307761&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3321329&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3306888&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307432&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307792&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3267435&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3335194&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3323898&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3322637&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3337797&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3296301&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3265078&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3307765&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3347142&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3271812&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3268910&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3268787&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3285740&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3266427&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3266122&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3265030&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3322993&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3266328&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3264967&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3327951&reply_limit=4&sorted_by=newest
# Error en la solicitud: 404 Client Error: Not Found for url: https://livecomments.viafoura.co/v4/livecomments/00000000-0000-4000-8000-9c5d48314ca1?limit=100&container_id=3345429&reply_limit=4&sorted_by=newest

# %%
articles.to_excel('articulos_eltiempo.xlsx',index=False)
